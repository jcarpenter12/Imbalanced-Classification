# %%
#import libraries

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from IPython.display import display
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv('./data/train.csv')
df_test  = pd.read_csv('./data/test.csv')

# %%
def summary(df):
    """
    Prints summary of data
    
    Arguments: df - pd.DataFrame
    
    Returns: None
    """
    
    print("number of rows: %s" % len(df.index))
    print("number of columns: %s" % len(df.columns.values))
    print("List of columns %s" % df.columns.values)
    display(df.head())
    
    return None

summary(df_train)
summary(df_test)
# Out:
# number of rows: 199523
# number of columns: 41
# List of columns ['age' 'class_of_worker' 'industry_code' 'occupation_code' 'education'
#  'wage_per_hour' 'enrolled_in_edu_inst_lastwk' 'marital_status'
#  'major_industry_code' 'major_occupation_code' 'race' 'hispanic_origin'
#  'sex' 'member_of_labor_union' 'reason_for_unemployment'
#  'full_parttime_employment_stat' 'capital_gains' 'capital_losses'
#  'dividend_from_Stocks' 'tax_filer_status' 'region_of_previous_residence'
#  'state_of_previous_residence' 'd_household_family_stat'
#  'd_household_summary' 'migration_msa' 'migration_reg'
#  'migration_within_reg' 'live_1_year_ago' 'migration_sunbelt'
#  'num_person_Worked_employer' 'family_members_under_18' 'country_father'
#  'country_mother' 'country_self' 'citizenship' 'business_or_self_employed'
#  'fill_questionnaire_veteran_admin' 'veterans_benefits'
#  'weeks_worked_in_year' 'year' 'income_level']
#    age                 class_of_worker  industry_code  occupation_code  \
# 0   73                 Not in universe              0                0
# 1   58  Self-employed-not incorporated              4               34
# 2   18                 Not in universe              0                0
# 3    9                 Not in universe              0                0
# 4   10                 Not in universe              0                0
#
#                     education  wage_per_hour enrolled_in_edu_inst_lastwk  \
# 0        High school graduate              0             Not in universe
# 1  Some college but no degree              0             Not in universe
# 2                  10th grade              0                 High school
# 3                    Children              0             Not in universe
# 4                    Children              0             Not in universe
#
#   marital_status          major_industry_code  \
# 0        Widowed  Not in universe or children
# 1       Divorced                 Construction
# 2  Never married  Not in universe or children
# 3  Never married  Not in universe or children
# 4  Never married  Not in universe or children
#
#                  major_occupation_code     ...      country_father  \
# 0                      Not in universe     ...       United-States
# 1  Precision production craft & repair     ...       United-States
# 2                      Not in universe     ...             Vietnam
# 3                      Not in universe     ...       United-States
# 4                      Not in universe     ...       United-States
#
#   country_mother   country_self                         citizenship  \
# 0  United-States  United-States   Native- Born in the United States
# 1  United-States  United-States   Native- Born in the United States
# 2        Vietnam        Vietnam  Foreign born- Not a citizen of U S
# 3  United-States  United-States   Native- Born in the United States
# 4  United-States  United-States   Native- Born in the United States
#
#   business_or_self_employed fill_questionnaire_veteran_admin  \
# 0                         0                  Not in universe
# 1                         0                  Not in universe
# 2                         0                  Not in universe
# 3                         0                  Not in universe
# 4                         0                  Not in universe
#
#    veterans_benefits  weeks_worked_in_year  year income_level
# 0                  2                     0    95       -50000
# 1                  2                    52    94       -50000
# 2                  2                     0    95       -50000
# 3                  0                     0    94       -50000
# 4                  0                     0    94       -50000
#
# [5 rows x 41 columns]
# number of rows: 99762
# number of columns: 41
# List of columns ['age' 'class_of_worker' 'industry_code' 'occupation_code' 'education'
#  'wage_per_hour' 'enrolled_in_edu_inst_lastwk' 'marital_status'
#  'major_industry_code' 'major_occupation_code' 'race' 'hispanic_origin'
#  'sex' 'member_of_labor_union' 'reason_for_unemployment'
#  'full_parttime_employment_stat' 'capital_gains' 'capital_losses'
#  'dividend_from_Stocks' 'tax_filer_status' 'region_of_previous_residence'
#  'state_of_previous_residence' 'd_household_family_stat'
#  'd_household_summary' 'migration_msa' 'migration_reg'
#  'migration_within_reg' 'live_1_year_ago' 'migration_sunbelt'
#  'num_person_Worked_employer' 'family_members_under_18' 'country_father'
#  'country_mother' 'country_self' 'citizenship' 'business_or_self_employed'
#  'fill_questionnaire_veteran_admin' 'veterans_benefits'
#  'weeks_worked_in_year' 'year' 'income_level']
#    age                  class_of_worker  industry_code  occupation_code  \
# 0   38                          Private              6               36
# 1   44   Self-employed-not incorporated             37               12
# 2    2                  Not in universe              0                0
# 3   35                          Private             29                3
# 4   49                          Private              4               34
#
#                               education  wage_per_hour  \
# 0              1st 2nd 3rd or 4th grade              0
# 1   Associates degree-occup /vocational              0
# 2                              Children              0
# 3                  High school graduate              0
# 4                  High school graduate              0
#
#   enrolled_in_edu_inst_lastwk                    marital_status  \
# 0             Not in universe   Married-civilian spouse present
# 1             Not in universe   Married-civilian spouse present
# 2             Not in universe                     Never married
# 3             Not in universe                          Divorced
# 4             Not in universe                          Divorced
#
#              major_industry_code                   major_occupation_code  \
# 0    Manufacturing-durable goods   Machine operators assmblrs & inspctrs
# 1   Business and repair services                  Professional specialty
# 2    Not in universe or children                         Not in universe
# 3                 Transportation          Executive admin and managerial
# 4                   Construction     Precision production craft & repair
#
#       ...       country_father  country_mother    country_self  \
# 0     ...               Mexico          Mexico          Mexico
# 1     ...        United-States   United-States   United-States
# 2     ...        United-States   United-States   United-States
# 3     ...        United-States   United-States   United-States
# 4     ...        United-States   United-States   United-States
#
#                             citizenship business_or_self_employed  \
# 0   Foreign born- Not a citizen of U S                          0
# 1     Native- Born in the United States                         0
# 2     Native- Born in the United States                         0
# 3     Native- Born in the United States                         2
# 4     Native- Born in the United States                         0
#
#   fill_questionnaire_veteran_admin  veterans_benefits  weeks_worked_in_year  \
# 0                  Not in universe                  2                    12
# 1                  Not in universe                  2                    26
# 2                  Not in universe                  0                     0
# 3                  Not in universe                  2                    52
# 4                  Not in universe                  2                    50
#
#    year income_level
# 0    95       -50000
# 1    95       -50000
# 2    95       -50000
# 3    94       -50000
# 4    95       -50000
#
# [5 rows x 41 columns]

# %%
#combine both train and test to group low frequency columns 
#this avoids categories that may not have been grouped in train being grouped in test(see below)
group = pd.concat([df_train,df_test],axis=0) 
group.reset_index(inplace=True)
del group['index']
group[len(df_train.index):]
# Out:
#         age                  class_of_worker  industry_code  occupation_code  \
# 199523   38                          Private              6               36
# 199524   44   Self-employed-not incorporated             37               12
# 199525    2                  Not in universe              0                0
# 199526   35                          Private             29                3
# 199527   49                          Private              4               34
# 199528   13                  Not in universe              0                0
# 199529    1                  Not in universe              0                0
# 199530   61                  Not in universe              0                0
# 199531   38                          Private             45               12
# 199532    7                  Not in universe              0                0
# 199533   30                          Private             30               26
# 199534   85                  Not in universe              0                0
# 199535   33                          Private             36               27
# 199536   26                          Private             33               29
# 199537   46                          Private             37               21
# 199538   19                          Private             33               26
# 199539   11                  Not in universe              0                0
# 199540   23                          Private             45               26
# 199541   27                          Private             37               31
# 199542   35   Self-employed-not incorporated              4                2
# 199543    8                  Not in universe              0                0
# 199544   29                  Not in universe              0                0
# 199545   40                          Private             42                2
# 199546   24                          Private             33               16
# 199547   45                          Private             33               16
# 199548   27                          Private             40               23
# 199549   41                 Local government             47               28
# 199550   14                  Not in universe              0                0
# 199551   73                  Not in universe              0                0
# 199552   46                          Private             32               33
# ...     ...                              ...            ...              ...
# 299255   54                          Private             45               12
# 299256    0                  Not in universe              0                0
# 299257   45                  Not in universe              0                0
# 299258   45                          Private             40               31
# 299259   30                          Private             33               16
# 299260   73                  Not in universe              0                0
# 299261    4                  Not in universe              0                0
# 299262    5                  Not in universe              0                0
# 299263   40                          Private             37               26
# 299264   52               Federal government             34               26
# 299265   20                          Private              2               44
# 299266    7                  Not in universe              0                0
# 299267   55                          Private             34               17
# 299268   75                  Not in universe              0                0
# 299269    0                  Not in universe              0                0
# 299270   57                          Private             24                2
# 299271   22                          Private             40               44
# 299272   48                          Private             35               26
# 299273   23                  Not in universe              0                0
# 299274   22                          Private             43               26
# 299275   46                          Private             44                3
# 299276    2                  Not in universe              0                0
# 299277   17                          Private             33               29
# 299278   20                  Not in universe              0                0
# 299279    4                  Not in universe              0                0
# 299280   14                  Not in universe              0                0
# 299281   61                          Private              8               36
# 299282   24   Self-employed-not incorporated              1               43
# 299283   30                          Private             45                2
# 299284   67                  Not in universe              0                0
#
#                                       education  wage_per_hour  \
# 199523                 1st 2nd 3rd or 4th grade              0
# 199524      Associates degree-occup /vocational              0
# 199525                                 Children              0
# 199526                     High school graduate              0
# 199527                     High school graduate              0
# 199528                                 Children              0
# 199529                                 Children              0
# 199530                     High school graduate              0
# 199531   Masters degree(MA MS MEng MEd MSW MBA)              0
# 199532                                 Children              0
# 199533               Bachelors degree(BA AB BS)              0
# 199534                               10th grade              0
# 199535                     High school graduate              0
# 199536               Some college but no degree            425
# 199537                     High school graduate              0
# 199538               Some college but no degree              0
# 199539                                 Children              0
# 199540               Bachelors degree(BA AB BS)              0
# 199541                     High school graduate              0
# 199542                     High school graduate              0
# 199543                                 Children              0
# 199544                     High school graduate              0
# 199545               Some college but no degree              0
# 199546                     High school graduate              0
# 199547               Some college but no degree            930
# 199548               Some college but no degree              0
# 199549                     High school graduate              0
# 199550                                 Children              0
# 199551                        7th and 8th grade              0
# 199552               Some college but no degree              0
# ...                                         ...            ...
# 299255   Masters degree(MA MS MEng MEd MSW MBA)              0
# 299256                                 Children              0
# 299257                        7th and 8th grade              0
# 299258                     High school graduate           1026
# 299259               Bachelors degree(BA AB BS)           1200
# 299260                               10th grade              0
# 299261                                 Children              0
# 299262                                 Children              0
# 299263                     High school graduate              0
# 299264                     High school graduate              0
# 299265                     High school graduate              0
# 299266                                 Children              0
# 299267   Masters degree(MA MS MEng MEd MSW MBA)              0
# 299268               Bachelors degree(BA AB BS)              0
# 299269                                 Children              0
# 299270               Some college but no degree              0
# 299271               Some college but no degree              0
# 299272                     High school graduate              0
# 299273                     High school graduate              0
# 299274               Some college but no degree              0
# 299275               Some college but no degree              0
# 299276                                 Children              0
# 299277                               10th grade              0
# 299278               Some college but no degree              0
# 299279                                 Children              0
# 299280                                 Children              0
# 299281                               11th grade              0
# 299282                        7th and 8th grade              0
# 299283               Bachelors degree(BA AB BS)              0
# 299284                                9th grade              0
#
#        enrolled_in_edu_inst_lastwk                    marital_status  \
# 199523             Not in universe   Married-civilian spouse present
# 199524             Not in universe   Married-civilian spouse present
# 199525             Not in universe                     Never married
# 199526             Not in universe                          Divorced
# 199527             Not in universe                          Divorced
# 199528             Not in universe                     Never married
# 199529             Not in universe                     Never married
# 199530             Not in universe   Married-civilian spouse present
# 199531             Not in universe   Married-civilian spouse present
# 199532             Not in universe                     Never married
# 199533             Not in universe   Married-civilian spouse present
# 199534             Not in universe   Married-civilian spouse present
# 199535             Not in universe   Married-civilian spouse present
# 199536             Not in universe                     Never married
# 199537             Not in universe   Married-civilian spouse present
# 199538       College or university                     Never married
# 199539             Not in universe                     Never married
# 199540       College or university   Married-civilian spouse present
# 199541             Not in universe   Married-civilian spouse present
# 199542             Not in universe                          Divorced
# 199543             Not in universe                     Never married
# 199544             Not in universe   Married-civilian spouse present
# 199545             Not in universe                          Divorced
# 199546             Not in universe   Married-civilian spouse present
# 199547             Not in universe   Married-civilian spouse present
# 199548             Not in universe                     Never married
# 199549             Not in universe   Married-civilian spouse present
# 199550             Not in universe                     Never married
# 199551             Not in universe   Married-civilian spouse present
# 199552             Not in universe   Married-civilian spouse present
# ...                            ...                               ...
# 299255             Not in universe   Married-civilian spouse present
# 299256             Not in universe                     Never married
# 299257             Not in universe   Married-civilian spouse present
# 299258             Not in universe   Married-civilian spouse present
# 299259             Not in universe                     Never married
# 299260             Not in universe                     Never married
# 299261             Not in universe                     Never married
# 299262             Not in universe                     Never married
# 299263             Not in universe   Married-civilian spouse present
# 299264             Not in universe                           Widowed
# 299265             Not in universe                     Never married
# 299266             Not in universe                     Never married
# 299267             Not in universe   Married-civilian spouse present
# 299268             Not in universe                           Widowed
# 299269             Not in universe                     Never married
# 299270             Not in universe   Married-civilian spouse present
# 299271             Not in universe                     Never married
# 299272             Not in universe                          Divorced
# 299273             Not in universe   Married-civilian spouse present
# 299274       College or university                     Never married
# 299275             Not in universe   Married-civilian spouse present
# 299276             Not in universe                     Never married
# 299277                 High school                     Never married
# 299278       College or university                     Never married
# 299279             Not in universe                     Never married
# 299280             Not in universe                     Never married
# 299281             Not in universe                         Separated
# 299282             Not in universe   Married-civilian spouse present
# 299283             Not in universe   Married-civilian spouse present
# 299284             Not in universe   Married-civilian spouse present
#
#                        major_industry_code  \
# 199523         Manufacturing-durable goods
# 199524        Business and repair services
# 199525         Not in universe or children
# 199526                      Transportation
# 199527                        Construction
# 199528         Not in universe or children
# 199529         Not in universe or children
# 199530         Not in universe or children
# 199531         Other professional services
# 199532         Not in universe or children
# 199533                      Communications
# 199534         Not in universe or children
# 199535          Private household services
# 199536                        Retail trade
# 199537        Business and repair services
# 199538                        Retail trade
# 199539         Not in universe or children
# 199540         Other professional services
# 199541        Business and repair services
# 199542                        Construction
# 199543         Not in universe or children
# 199544         Not in universe or children
# 199545             Medical except hospital
# 199546                        Retail trade
# 199547                        Retail trade
# 199548                       Entertainment
# 199549               Public administration
# 199550         Not in universe or children
# 199551         Not in universe or children
# 199552                     Wholesale trade
# ...                                    ...
# 299255         Other professional services
# 299256         Not in universe or children
# 299257         Not in universe or children
# 299258                       Entertainment
# 299259                        Retail trade
# 299260         Not in universe or children
# 299261         Not in universe or children
# 299262         Not in universe or children
# 299263        Business and repair services
# 299264   Finance insurance and real estate
# 299265                         Agriculture
# 299266         Not in universe or children
# 299267   Finance insurance and real estate
# 299268         Not in universe or children
# 299269         Not in universe or children
# 299270      Manufacturing-nondurable goods
# 299271                       Entertainment
# 299272   Finance insurance and real estate
# 299273         Not in universe or children
# 299274                           Education
# 299275                     Social services
# 299276         Not in universe or children
# 299277                        Retail trade
# 299278         Not in universe or children
# 299279         Not in universe or children
# 299280         Not in universe or children
# 299281         Manufacturing-durable goods
# 299282                         Agriculture
# 299283         Other professional services
# 299284         Not in universe or children
#
#                          major_occupation_code     ...         country_father  \
# 199523   Machine operators assmblrs & inspctrs     ...                 Mexico
# 199524                  Professional specialty     ...          United-States
# 199525                         Not in universe     ...          United-States
# 199526          Executive admin and managerial     ...          United-States
# 199527     Precision production craft & repair     ...          United-States
# 199528                         Not in universe     ...                Germany
# 199529                         Not in universe     ...                 Mexico
# 199530                         Not in universe     ...          United-States
# 199531                  Professional specialty     ...          United-States
# 199532                         Not in universe     ...          United-States
# 199533          Adm support including clerical     ...          United-States
# 199534                         Not in universe     ...          United-States
# 199535              Private household services     ...        Trinadad&Tobago
# 199536                           Other service     ...          United-States
# 199537          Adm support including clerical     ...          United-States
# 199538          Adm support including clerical     ...          United-States
# 199539                         Not in universe     ...                 Mexico
# 199540          Adm support including clerical     ...          United-States
# 199541                           Other service     ...                      ?
# 199542          Executive admin and managerial     ...          United-States
# 199543                         Not in universe     ...          United-States
# 199544                         Not in universe     ...          United-States
# 199545          Executive admin and managerial     ...                      ?
# 199546                                   Sales     ...          United-States
# 199547                                   Sales     ...          United-States
# 199548          Adm support including clerical     ...          United-States
# 199549                     Protective services     ...          United-States
# 199550                         Not in universe     ...          United-States
# 199551                         Not in universe     ...                      ?
# 199552     Precision production craft & repair     ...          United-States
# ...                                        ...     ...                    ...
# 299255                  Professional specialty     ...          United-States
# 299256                         Not in universe     ...          United-States
# 299257                         Not in universe     ...                 Mexico
# 299258                           Other service     ...            Philippines
# 299259                                   Sales     ...          United-States
# 299260                         Not in universe     ...                  Italy
# 299261                         Not in universe     ...          United-States
# 299262                         Not in universe     ...          United-States
# 299263          Adm support including clerical     ...          United-States
# 299264          Adm support including clerical     ...          United-States
# 299265            Farming forestry and fishing     ...          United-States
# 299266                         Not in universe     ...          United-States
# 299267                                   Sales     ...          United-States
# 299268                         Not in universe     ...          United-States
# 299269                         Not in universe     ...          United-States
# 299270          Executive admin and managerial     ...          United-States
# 299271            Farming forestry and fishing     ...          United-States
# 299272          Adm support including clerical     ...          United-States
# 299273                         Not in universe     ...                England
# 299274          Adm support including clerical     ...          United-States
# 299275          Executive admin and managerial     ...          United-States
# 299276                         Not in universe     ...          United-States
# 299277                           Other service     ...          United-States
# 299278                         Not in universe     ...          United-States
# 299279                         Not in universe     ...          United-States
# 299280                         Not in universe     ...          United-States
# 299281   Machine operators assmblrs & inspctrs     ...          United-States
# 299282            Farming forestry and fishing     ...                 Mexico
# 299283          Executive admin and managerial     ...          United-States
# 299284                         Not in universe     ...          United-States
#
#           country_mother      country_self  \
# 199523            Mexico            Mexico
# 199524     United-States     United-States
# 199525     United-States     United-States
# 199526     United-States     United-States
# 199527     United-States     United-States
# 199528     United-States     United-States
# 199529     United-States     United-States
# 199530     United-States     United-States
# 199531     United-States     United-States
# 199532     United-States     United-States
# 199533     United-States     United-States
# 199534     United-States     United-States
# 199535   Trinadad&Tobago   Trinadad&Tobago
# 199536     United-States     United-States
# 199537     United-States     United-States
# 199538     United-States     United-States
# 199539     United-States     United-States
# 199540     United-States     United-States
# 199541                 ?                 ?
# 199542     United-States     United-States
# 199543     United-States     United-States
# 199544     United-States     United-States
# 199545                 ?                 ?
# 199546     United-States     United-States
# 199547     United-States     United-States
# 199548     United-States     United-States
# 199549     United-States     United-States
# 199550     United-States     United-States
# 199551                 ?     United-States
# 199552     United-States     United-States
# ...                  ...               ...
# 299255     United-States     United-States
# 299256     United-States     United-States
# 299257            Mexico            Mexico
# 299258       Philippines       Philippines
# 299259     United-States     United-States
# 299260             Italy     United-States
# 299261     United-States     United-States
# 299262     United-States     United-States
# 299263     United-States     United-States
# 299264     United-States     United-States
# 299265     United-States     United-States
# 299266     United-States     United-States
# 299267     United-States     United-States
# 299268            Canada     United-States
# 299269     United-States     United-States
# 299270     United-States     United-States
# 299271     United-States     United-States
# 299272                 ?     United-States
# 299273           England           England
# 299274     United-States     United-States
# 299275     United-States     United-States
# 299276     United-States     United-States
# 299277     United-States     United-States
# 299278     United-States     United-States
# 299279     United-States     United-States
# 299280     United-States     United-States
# 299281     United-States     United-States
# 299282            Mexico            Mexico
# 299283     United-States     United-States
# 299284     United-States     United-States
#
#                                          citizenship  \
# 199523           Foreign born- Not a citizen of U S
# 199524             Native- Born in the United States
# 199525             Native- Born in the United States
# 199526             Native- Born in the United States
# 199527             Native- Born in the United States
# 199528             Native- Born in the United States
# 199529             Native- Born in the United States
# 199530             Native- Born in the United States
# 199531             Native- Born in the United States
# 199532             Native- Born in the United States
# 199533             Native- Born in the United States
# 199534             Native- Born in the United States
# 199535           Foreign born- Not a citizen of U S
# 199536             Native- Born in the United States
# 199537             Native- Born in the United States
# 199538             Native- Born in the United States
# 199539             Native- Born in the United States
# 199540             Native- Born in the United States
# 199541           Foreign born- Not a citizen of U S
# 199542             Native- Born in the United States
# 199543             Native- Born in the United States
# 199544             Native- Born in the United States
# 199545   Foreign born- U S citizen by naturalization
# 199546             Native- Born in the United States
# 199547             Native- Born in the United States
# 199548             Native- Born in the United States
# 199549             Native- Born in the United States
# 199550             Native- Born in the United States
# 199551             Native- Born in the United States
# 199552             Native- Born in the United States
# ...                                              ...
# 299255             Native- Born in the United States
# 299256             Native- Born in the United States
# 299257   Foreign born- U S citizen by naturalization
# 299258   Foreign born- U S citizen by naturalization
# 299259             Native- Born in the United States
# 299260             Native- Born in the United States
# 299261             Native- Born in the United States
# 299262             Native- Born in the United States
# 299263             Native- Born in the United States
# 299264             Native- Born in the United States
# 299265             Native- Born in the United States
# 299266             Native- Born in the United States
# 299267             Native- Born in the United States
# 299268             Native- Born in the United States
# 299269             Native- Born in the United States
# 299270             Native- Born in the United States
# 299271             Native- Born in the United States
# 299272             Native- Born in the United States
# 299273           Foreign born- Not a citizen of U S
# 299274             Native- Born in the United States
# 299275             Native- Born in the United States
# 299276             Native- Born in the United States
# 299277             Native- Born in the United States
# 299278             Native- Born in the United States
# 299279             Native- Born in the United States
# 299280             Native- Born in the United States
# 299281             Native- Born in the United States
# 299282   Foreign born- U S citizen by naturalization
# 299283             Native- Born in the United States
# 299284             Native- Born in the United States
#
#        business_or_self_employed fill_questionnaire_veteran_admin  \
# 199523                         0                  Not in universe
# 199524                         0                  Not in universe
# 199525                         0                  Not in universe
# 199526                         2                  Not in universe
# 199527                         0                  Not in universe
# 199528                         0                  Not in universe
# 199529                         0                  Not in universe
# 199530                         0                  Not in universe
# 199531                         0                  Not in universe
# 199532                         0                  Not in universe
# 199533                         0                  Not in universe
# 199534                         0                  Not in universe
# 199535                         0                  Not in universe
# 199536                         0                  Not in universe
# 199537                         0                  Not in universe
# 199538                         0                  Not in universe
# 199539                         0                  Not in universe
# 199540                         0                  Not in universe
# 199541                         1                  Not in universe
# 199542                         0                  Not in universe
# 199543                         0                  Not in universe
# 199544                         0                  Not in universe
# 199545                         0                  Not in universe
# 199546                         0                  Not in universe
# 199547                         0                  Not in universe
# 199548                         0                  Not in universe
# 199549                         0                  Not in universe
# 199550                         0                  Not in universe
# 199551                         0                  Not in universe
# 199552                         0                  Not in universe
# ...                          ...                              ...
# 299255                         0                  Not in universe
# 299256                         0                  Not in universe
# 299257                         0                  Not in universe
# 299258                         0                  Not in universe
# 299259                         0                  Not in universe
# 299260                         0                  Not in universe
# 299261                         0                  Not in universe
# 299262                         0                  Not in universe
# 299263                         1                  Not in universe
# 299264                         0                  Not in universe
# 299265                         0                  Not in universe
# 299266                         0                  Not in universe
# 299267                         0                  Not in universe
# 299268                         0                  Not in universe
# 299269                         0                  Not in universe
# 299270                         0                  Not in universe
# 299271                         0                  Not in universe
# 299272                         0                  Not in universe
# 299273                         0                  Not in universe
# 299274                         0                  Not in universe
# 299275                         0                  Not in universe
# 299276                         0                  Not in universe
# 299277                         0                  Not in universe
# 299278                         0                  Not in universe
# 299279                         0                  Not in universe
# 299280                         0                  Not in universe
# 299281                         0                  Not in universe
# 299282                         0                  Not in universe
# 299283                         0                  Not in universe
# 299284                         0                  Not in universe
#
#         veterans_benefits  weeks_worked_in_year  year income_level
# 199523                  2                    12    95       -50000
# 199524                  2                    26    95       -50000
# 199525                  0                     0    95       -50000
# 199526                  2                    52    94       -50000
# 199527                  2                    50    95       -50000
# 199528                  0                     0    94       -50000
# 199529                  0                     0    94       -50000
# 199530                  2                     0    95       -50000
# 199531                  2                    52    94       -50000
# 199532                  0                     0    94       -50000
# 199533                  2                    52    95       -50000
# 199534                  2                     0    95       -50000
# 199535                  2                    30    94       -50000
# 199536                  2                    17    94       -50000
# 199537                  2                    52    95       -50000
# 199538                  2                    52    95       -50000
# 199539                  0                     0    95       -50000
# 199540                  2                    52    95       -50000
# 199541                  2                    50    94       -50000
# 199542                  2                    52    95      50000+.
# 199543                  0                     0    94       -50000
# 199544                  2                     0    94       -50000
# 199545                  2                    52    95       -50000
# 199546                  2                    52    94       -50000
# 199547                  2                    52    94       -50000
# 199548                  2                    52    94       -50000
# 199549                  2                    52    94       -50000
# 199550                  0                     0    94       -50000
# 199551                  2                     0    95       -50000
# 199552                  2                    36    94       -50000
# ...                   ...                   ...   ...          ...
# 299255                  2                    30    94       -50000
# 299256                  0                     0    95       -50000
# 299257                  2                     0    94       -50000
# 299258                  2                    52    95       -50000
# 299259                  2                    52    94       -50000
# 299260                  2                     1    94       -50000
# 299261                  0                     0    94       -50000
# 299262                  0                     0    95       -50000
# 299263                  2                    48    95       -50000
# 299264                  2                    52    95       -50000
# 299265                  2                    26    95       -50000
# 299266                  0                     0    95       -50000
# 299267                  2                    52    95       -50000
# 299268                  2                     0    95       -50000
# 299269                  0                     0    94       -50000
# 299270                  2                    52    95       -50000
# 299271                  2                    27    95       -50000
# 299272                  2                    52    94       -50000
# 299273                  2                     0    94       -50000
# 299274                  2                    52    94       -50000
# 299275                  2                    52    95       -50000
# 299276                  0                     0    95       -50000
# 299277                  2                     1    95       -50000
# 299278                  2                     0    95       -50000
# 299279                  0                     0    95       -50000
# 299280                  0                     0    95       -50000
# 299281                  2                    52    95       -50000
# 299282                  2                    52    94       -50000
# 299283                  2                    52    95       -50000
# 299284                  2                     0    94       -50000
#
# [99762 rows x 41 columns]

# %%
def convert_income_level(df):
    """
    Converts income_level_column to 0/1
    
    Arguments: df - pd.DataFrame
    
    Returns: x - pd.DataFrame
    
    """
    
    #Assign df to x
    x = df
    x['income_level'] = x['income_level'].astype(str)
    x['income_level'] = np.where(x['income_level'] == '-50000',0,1)
    
    return x

group = convert_income_level(group)

# %%
display(group.head())

group[len(df_train.index):]
# Out:
#    age                 class_of_worker  industry_code  occupation_code  \
# 0   73                 Not in universe              0                0
# 1   58  Self-employed-not incorporated              4               34
# 2   18                 Not in universe              0                0
# 3    9                 Not in universe              0                0
# 4   10                 Not in universe              0                0
#
#                     education  wage_per_hour enrolled_in_edu_inst_lastwk  \
# 0        High school graduate              0             Not in universe
# 1  Some college but no degree              0             Not in universe
# 2                  10th grade              0                 High school
# 3                    Children              0             Not in universe
# 4                    Children              0             Not in universe
#
#   marital_status          major_industry_code  \
# 0        Widowed  Not in universe or children
# 1       Divorced                 Construction
# 2  Never married  Not in universe or children
# 3  Never married  Not in universe or children
# 4  Never married  Not in universe or children
#
#                  major_occupation_code     ...      country_father  \
# 0                      Not in universe     ...       United-States
# 1  Precision production craft & repair     ...       United-States
# 2                      Not in universe     ...             Vietnam
# 3                      Not in universe     ...       United-States
# 4                      Not in universe     ...       United-States
#
#   country_mother   country_self                         citizenship  \
# 0  United-States  United-States   Native- Born in the United States
# 1  United-States  United-States   Native- Born in the United States
# 2        Vietnam        Vietnam  Foreign born- Not a citizen of U S
# 3  United-States  United-States   Native- Born in the United States
# 4  United-States  United-States   Native- Born in the United States
#
#   business_or_self_employed fill_questionnaire_veteran_admin  \
# 0                         0                  Not in universe
# 1                         0                  Not in universe
# 2                         0                  Not in universe
# 3                         0                  Not in universe
# 4                         0                  Not in universe
#
#    veterans_benefits  weeks_worked_in_year  year income_level
# 0                  2                     0    95            0
# 1                  2                    52    94            0
# 2                  2                     0    95            0
# 3                  0                     0    94            0
# 4                  0                     0    94            0
#
# [5 rows x 41 columns]
#         age                  class_of_worker  industry_code  occupation_code  \
# 199523   38                          Private              6               36
# 199524   44   Self-employed-not incorporated             37               12
# 199525    2                  Not in universe              0                0
# 199526   35                          Private             29                3
# 199527   49                          Private              4               34
# 199528   13                  Not in universe              0                0
# 199529    1                  Not in universe              0                0
# 199530   61                  Not in universe              0                0
# 199531   38                          Private             45               12
# 199532    7                  Not in universe              0                0
# 199533   30                          Private             30               26
# 199534   85                  Not in universe              0                0
# 199535   33                          Private             36               27
# 199536   26                          Private             33               29
# 199537   46                          Private             37               21
# 199538   19                          Private             33               26
# 199539   11                  Not in universe              0                0
# 199540   23                          Private             45               26
# 199541   27                          Private             37               31
# 199542   35   Self-employed-not incorporated              4                2
# 199543    8                  Not in universe              0                0
# 199544   29                  Not in universe              0                0
# 199545   40                          Private             42                2
# 199546   24                          Private             33               16
# 199547   45                          Private             33               16
# 199548   27                          Private             40               23
# 199549   41                 Local government             47               28
# 199550   14                  Not in universe              0                0
# 199551   73                  Not in universe              0                0
# 199552   46                          Private             32               33
# ...     ...                              ...            ...              ...
# 299255   54                          Private             45               12
# 299256    0                  Not in universe              0                0
# 299257   45                  Not in universe              0                0
# 299258   45                          Private             40               31
# 299259   30                          Private             33               16
# 299260   73                  Not in universe              0                0
# 299261    4                  Not in universe              0                0
# 299262    5                  Not in universe              0                0
# 299263   40                          Private             37               26
# 299264   52               Federal government             34               26
# 299265   20                          Private              2               44
# 299266    7                  Not in universe              0                0
# 299267   55                          Private             34               17
# 299268   75                  Not in universe              0                0
# 299269    0                  Not in universe              0                0
# 299270   57                          Private             24                2
# 299271   22                          Private             40               44
# 299272   48                          Private             35               26
# 299273   23                  Not in universe              0                0
# 299274   22                          Private             43               26
# 299275   46                          Private             44                3
# 299276    2                  Not in universe              0                0
# 299277   17                          Private             33               29
# 299278   20                  Not in universe              0                0
# 299279    4                  Not in universe              0                0
# 299280   14                  Not in universe              0                0
# 299281   61                          Private              8               36
# 299282   24   Self-employed-not incorporated              1               43
# 299283   30                          Private             45                2
# 299284   67                  Not in universe              0                0
#
#                                       education  wage_per_hour  \
# 199523                 1st 2nd 3rd or 4th grade              0
# 199524      Associates degree-occup /vocational              0
# 199525                                 Children              0
# 199526                     High school graduate              0
# 199527                     High school graduate              0
# 199528                                 Children              0
# 199529                                 Children              0
# 199530                     High school graduate              0
# 199531   Masters degree(MA MS MEng MEd MSW MBA)              0
# 199532                                 Children              0
# 199533               Bachelors degree(BA AB BS)              0
# 199534                               10th grade              0
# 199535                     High school graduate              0
# 199536               Some college but no degree            425
# 199537                     High school graduate              0
# 199538               Some college but no degree              0
# 199539                                 Children              0
# 199540               Bachelors degree(BA AB BS)              0
# 199541                     High school graduate              0
# 199542                     High school graduate              0
# 199543                                 Children              0
# 199544                     High school graduate              0
# 199545               Some college but no degree              0
# 199546                     High school graduate              0
# 199547               Some college but no degree            930
# 199548               Some college but no degree              0
# 199549                     High school graduate              0
# 199550                                 Children              0
# 199551                        7th and 8th grade              0
# 199552               Some college but no degree              0
# ...                                         ...            ...
# 299255   Masters degree(MA MS MEng MEd MSW MBA)              0
# 299256                                 Children              0
# 299257                        7th and 8th grade              0
# 299258                     High school graduate           1026
# 299259               Bachelors degree(BA AB BS)           1200
# 299260                               10th grade              0
# 299261                                 Children              0
# 299262                                 Children              0
# 299263                     High school graduate              0
# 299264                     High school graduate              0
# 299265                     High school graduate              0
# 299266                                 Children              0
# 299267   Masters degree(MA MS MEng MEd MSW MBA)              0
# 299268               Bachelors degree(BA AB BS)              0
# 299269                                 Children              0
# 299270               Some college but no degree              0
# 299271               Some college but no degree              0
# 299272                     High school graduate              0
# 299273                     High school graduate              0
# 299274               Some college but no degree              0
# 299275               Some college but no degree              0
# 299276                                 Children              0
# 299277                               10th grade              0
# 299278               Some college but no degree              0
# 299279                                 Children              0
# 299280                                 Children              0
# 299281                               11th grade              0
# 299282                        7th and 8th grade              0
# 299283               Bachelors degree(BA AB BS)              0
# 299284                                9th grade              0
#
#        enrolled_in_edu_inst_lastwk                    marital_status  \
# 199523             Not in universe   Married-civilian spouse present
# 199524             Not in universe   Married-civilian spouse present
# 199525             Not in universe                     Never married
# 199526             Not in universe                          Divorced
# 199527             Not in universe                          Divorced
# 199528             Not in universe                     Never married
# 199529             Not in universe                     Never married
# 199530             Not in universe   Married-civilian spouse present
# 199531             Not in universe   Married-civilian spouse present
# 199532             Not in universe                     Never married
# 199533             Not in universe   Married-civilian spouse present
# 199534             Not in universe   Married-civilian spouse present
# 199535             Not in universe   Married-civilian spouse present
# 199536             Not in universe                     Never married
# 199537             Not in universe   Married-civilian spouse present
# 199538       College or university                     Never married
# 199539             Not in universe                     Never married
# 199540       College or university   Married-civilian spouse present
# 199541             Not in universe   Married-civilian spouse present
# 199542             Not in universe                          Divorced
# 199543             Not in universe                     Never married
# 199544             Not in universe   Married-civilian spouse present
# 199545             Not in universe                          Divorced
# 199546             Not in universe   Married-civilian spouse present
# 199547             Not in universe   Married-civilian spouse present
# 199548             Not in universe                     Never married
# 199549             Not in universe   Married-civilian spouse present
# 199550             Not in universe                     Never married
# 199551             Not in universe   Married-civilian spouse present
# 199552             Not in universe   Married-civilian spouse present
# ...                            ...                               ...
# 299255             Not in universe   Married-civilian spouse present
# 299256             Not in universe                     Never married
# 299257             Not in universe   Married-civilian spouse present
# 299258             Not in universe   Married-civilian spouse present
# 299259             Not in universe                     Never married
# 299260             Not in universe                     Never married
# 299261             Not in universe                     Never married
# 299262             Not in universe                     Never married
# 299263             Not in universe   Married-civilian spouse present
# 299264             Not in universe                           Widowed
# 299265             Not in universe                     Never married
# 299266             Not in universe                     Never married
# 299267             Not in universe   Married-civilian spouse present
# 299268             Not in universe                           Widowed
# 299269             Not in universe                     Never married
# 299270             Not in universe   Married-civilian spouse present
# 299271             Not in universe                     Never married
# 299272             Not in universe                          Divorced
# 299273             Not in universe   Married-civilian spouse present
# 299274       College or university                     Never married
# 299275             Not in universe   Married-civilian spouse present
# 299276             Not in universe                     Never married
# 299277                 High school                     Never married
# 299278       College or university                     Never married
# 299279             Not in universe                     Never married
# 299280             Not in universe                     Never married
# 299281             Not in universe                         Separated
# 299282             Not in universe   Married-civilian spouse present
# 299283             Not in universe   Married-civilian spouse present
# 299284             Not in universe   Married-civilian spouse present
#
#                        major_industry_code  \
# 199523         Manufacturing-durable goods
# 199524        Business and repair services
# 199525         Not in universe or children
# 199526                      Transportation
# 199527                        Construction
# 199528         Not in universe or children
# 199529         Not in universe or children
# 199530         Not in universe or children
# 199531         Other professional services
# 199532         Not in universe or children
# 199533                      Communications
# 199534         Not in universe or children
# 199535          Private household services
# 199536                        Retail trade
# 199537        Business and repair services
# 199538                        Retail trade
# 199539         Not in universe or children
# 199540         Other professional services
# 199541        Business and repair services
# 199542                        Construction
# 199543         Not in universe or children
# 199544         Not in universe or children
# 199545             Medical except hospital
# 199546                        Retail trade
# 199547                        Retail trade
# 199548                       Entertainment
# 199549               Public administration
# 199550         Not in universe or children
# 199551         Not in universe or children
# 199552                     Wholesale trade
# ...                                    ...
# 299255         Other professional services
# 299256         Not in universe or children
# 299257         Not in universe or children
# 299258                       Entertainment
# 299259                        Retail trade
# 299260         Not in universe or children
# 299261         Not in universe or children
# 299262         Not in universe or children
# 299263        Business and repair services
# 299264   Finance insurance and real estate
# 299265                         Agriculture
# 299266         Not in universe or children
# 299267   Finance insurance and real estate
# 299268         Not in universe or children
# 299269         Not in universe or children
# 299270      Manufacturing-nondurable goods
# 299271                       Entertainment
# 299272   Finance insurance and real estate
# 299273         Not in universe or children
# 299274                           Education
# 299275                     Social services
# 299276         Not in universe or children
# 299277                        Retail trade
# 299278         Not in universe or children
# 299279         Not in universe or children
# 299280         Not in universe or children
# 299281         Manufacturing-durable goods
# 299282                         Agriculture
# 299283         Other professional services
# 299284         Not in universe or children
#
#                          major_occupation_code     ...         country_father  \
# 199523   Machine operators assmblrs & inspctrs     ...                 Mexico
# 199524                  Professional specialty     ...          United-States
# 199525                         Not in universe     ...          United-States
# 199526          Executive admin and managerial     ...          United-States
# 199527     Precision production craft & repair     ...          United-States
# 199528                         Not in universe     ...                Germany
# 199529                         Not in universe     ...                 Mexico
# 199530                         Not in universe     ...          United-States
# 199531                  Professional specialty     ...          United-States
# 199532                         Not in universe     ...          United-States
# 199533          Adm support including clerical     ...          United-States
# 199534                         Not in universe     ...          United-States
# 199535              Private household services     ...        Trinadad&Tobago
# 199536                           Other service     ...          United-States
# 199537          Adm support including clerical     ...          United-States
# 199538          Adm support including clerical     ...          United-States
# 199539                         Not in universe     ...                 Mexico
# 199540          Adm support including clerical     ...          United-States
# 199541                           Other service     ...                      ?
# 199542          Executive admin and managerial     ...          United-States
# 199543                         Not in universe     ...          United-States
# 199544                         Not in universe     ...          United-States
# 199545          Executive admin and managerial     ...                      ?
# 199546                                   Sales     ...          United-States
# 199547                                   Sales     ...          United-States
# 199548          Adm support including clerical     ...          United-States
# 199549                     Protective services     ...          United-States
# 199550                         Not in universe     ...          United-States
# 199551                         Not in universe     ...                      ?
# 199552     Precision production craft & repair     ...          United-States
# ...                                        ...     ...                    ...
# 299255                  Professional specialty     ...          United-States
# 299256                         Not in universe     ...          United-States
# 299257                         Not in universe     ...                 Mexico
# 299258                           Other service     ...            Philippines
# 299259                                   Sales     ...          United-States
# 299260                         Not in universe     ...                  Italy
# 299261                         Not in universe     ...          United-States
# 299262                         Not in universe     ...          United-States
# 299263          Adm support including clerical     ...          United-States
# 299264          Adm support including clerical     ...          United-States
# 299265            Farming forestry and fishing     ...          United-States
# 299266                         Not in universe     ...          United-States
# 299267                                   Sales     ...          United-States
# 299268                         Not in universe     ...          United-States
# 299269                         Not in universe     ...          United-States
# 299270          Executive admin and managerial     ...          United-States
# 299271            Farming forestry and fishing     ...          United-States
# 299272          Adm support including clerical     ...          United-States
# 299273                         Not in universe     ...                England
# 299274          Adm support including clerical     ...          United-States
# 299275          Executive admin and managerial     ...          United-States
# 299276                         Not in universe     ...          United-States
# 299277                           Other service     ...          United-States
# 299278                         Not in universe     ...          United-States
# 299279                         Not in universe     ...          United-States
# 299280                         Not in universe     ...          United-States
# 299281   Machine operators assmblrs & inspctrs     ...          United-States
# 299282            Farming forestry and fishing     ...                 Mexico
# 299283          Executive admin and managerial     ...          United-States
# 299284                         Not in universe     ...          United-States
#
#           country_mother      country_self  \
# 199523            Mexico            Mexico
# 199524     United-States     United-States
# 199525     United-States     United-States
# 199526     United-States     United-States
# 199527     United-States     United-States
# 199528     United-States     United-States
# 199529     United-States     United-States
# 199530     United-States     United-States
# 199531     United-States     United-States
# 199532     United-States     United-States
# 199533     United-States     United-States
# 199534     United-States     United-States
# 199535   Trinadad&Tobago   Trinadad&Tobago
# 199536     United-States     United-States
# 199537     United-States     United-States
# 199538     United-States     United-States
# 199539     United-States     United-States
# 199540     United-States     United-States
# 199541                 ?                 ?
# 199542     United-States     United-States
# 199543     United-States     United-States
# 199544     United-States     United-States
# 199545                 ?                 ?
# 199546     United-States     United-States
# 199547     United-States     United-States
# 199548     United-States     United-States
# 199549     United-States     United-States
# 199550     United-States     United-States
# 199551                 ?     United-States
# 199552     United-States     United-States
# ...                  ...               ...
# 299255     United-States     United-States
# 299256     United-States     United-States
# 299257            Mexico            Mexico
# 299258       Philippines       Philippines
# 299259     United-States     United-States
# 299260             Italy     United-States
# 299261     United-States     United-States
# 299262     United-States     United-States
# 299263     United-States     United-States
# 299264     United-States     United-States
# 299265     United-States     United-States
# 299266     United-States     United-States
# 299267     United-States     United-States
# 299268            Canada     United-States
# 299269     United-States     United-States
# 299270     United-States     United-States
# 299271     United-States     United-States
# 299272                 ?     United-States
# 299273           England           England
# 299274     United-States     United-States
# 299275     United-States     United-States
# 299276     United-States     United-States
# 299277     United-States     United-States
# 299278     United-States     United-States
# 299279     United-States     United-States
# 299280     United-States     United-States
# 299281     United-States     United-States
# 299282            Mexico            Mexico
# 299283     United-States     United-States
# 299284     United-States     United-States
#
#                                          citizenship  \
# 199523           Foreign born- Not a citizen of U S
# 199524             Native- Born in the United States
# 199525             Native- Born in the United States
# 199526             Native- Born in the United States
# 199527             Native- Born in the United States
# 199528             Native- Born in the United States
# 199529             Native- Born in the United States
# 199530             Native- Born in the United States
# 199531             Native- Born in the United States
# 199532             Native- Born in the United States
# 199533             Native- Born in the United States
# 199534             Native- Born in the United States
# 199535           Foreign born- Not a citizen of U S
# 199536             Native- Born in the United States
# 199537             Native- Born in the United States
# 199538             Native- Born in the United States
# 199539             Native- Born in the United States
# 199540             Native- Born in the United States
# 199541           Foreign born- Not a citizen of U S
# 199542             Native- Born in the United States
# 199543             Native- Born in the United States
# 199544             Native- Born in the United States
# 199545   Foreign born- U S citizen by naturalization
# 199546             Native- Born in the United States
# 199547             Native- Born in the United States
# 199548             Native- Born in the United States
# 199549             Native- Born in the United States
# 199550             Native- Born in the United States
# 199551             Native- Born in the United States
# 199552             Native- Born in the United States
# ...                                              ...
# 299255             Native- Born in the United States
# 299256             Native- Born in the United States
# 299257   Foreign born- U S citizen by naturalization
# 299258   Foreign born- U S citizen by naturalization
# 299259             Native- Born in the United States
# 299260             Native- Born in the United States
# 299261             Native- Born in the United States
# 299262             Native- Born in the United States
# 299263             Native- Born in the United States
# 299264             Native- Born in the United States
# 299265             Native- Born in the United States
# 299266             Native- Born in the United States
# 299267             Native- Born in the United States
# 299268             Native- Born in the United States
# 299269             Native- Born in the United States
# 299270             Native- Born in the United States
# 299271             Native- Born in the United States
# 299272             Native- Born in the United States
# 299273           Foreign born- Not a citizen of U S
# 299274             Native- Born in the United States
# 299275             Native- Born in the United States
# 299276             Native- Born in the United States
# 299277             Native- Born in the United States
# 299278             Native- Born in the United States
# 299279             Native- Born in the United States
# 299280             Native- Born in the United States
# 299281             Native- Born in the United States
# 299282   Foreign born- U S citizen by naturalization
# 299283             Native- Born in the United States
# 299284             Native- Born in the United States
#
#        business_or_self_employed fill_questionnaire_veteran_admin  \
# 199523                         0                  Not in universe
# 199524                         0                  Not in universe
# 199525                         0                  Not in universe
# 199526                         2                  Not in universe
# 199527                         0                  Not in universe
# 199528                         0                  Not in universe
# 199529                         0                  Not in universe
# 199530                         0                  Not in universe
# 199531                         0                  Not in universe
# 199532                         0                  Not in universe
# 199533                         0                  Not in universe
# 199534                         0                  Not in universe
# 199535                         0                  Not in universe
# 199536                         0                  Not in universe
# 199537                         0                  Not in universe
# 199538                         0                  Not in universe
# 199539                         0                  Not in universe
# 199540                         0                  Not in universe
# 199541                         1                  Not in universe
# 199542                         0                  Not in universe
# 199543                         0                  Not in universe
# 199544                         0                  Not in universe
# 199545                         0                  Not in universe
# 199546                         0                  Not in universe
# 199547                         0                  Not in universe
# 199548                         0                  Not in universe
# 199549                         0                  Not in universe
# 199550                         0                  Not in universe
# 199551                         0                  Not in universe
# 199552                         0                  Not in universe
# ...                          ...                              ...
# 299255                         0                  Not in universe
# 299256                         0                  Not in universe
# 299257                         0                  Not in universe
# 299258                         0                  Not in universe
# 299259                         0                  Not in universe
# 299260                         0                  Not in universe
# 299261                         0                  Not in universe
# 299262                         0                  Not in universe
# 299263                         1                  Not in universe
# 299264                         0                  Not in universe
# 299265                         0                  Not in universe
# 299266                         0                  Not in universe
# 299267                         0                  Not in universe
# 299268                         0                  Not in universe
# 299269                         0                  Not in universe
# 299270                         0                  Not in universe
# 299271                         0                  Not in universe
# 299272                         0                  Not in universe
# 299273                         0                  Not in universe
# 299274                         0                  Not in universe
# 299275                         0                  Not in universe
# 299276                         0                  Not in universe
# 299277                         0                  Not in universe
# 299278                         0                  Not in universe
# 299279                         0                  Not in universe
# 299280                         0                  Not in universe
# 299281                         0                  Not in universe
# 299282                         0                  Not in universe
# 299283                         0                  Not in universe
# 299284                         0                  Not in universe
#
#         veterans_benefits  weeks_worked_in_year  year income_level
# 199523                  2                    12    95            0
# 199524                  2                    26    95            0
# 199525                  0                     0    95            0
# 199526                  2                    52    94            0
# 199527                  2                    50    95            0
# 199528                  0                     0    94            0
# 199529                  0                     0    94            0
# 199530                  2                     0    95            0
# 199531                  2                    52    94            0
# 199532                  0                     0    94            0
# 199533                  2                    52    95            0
# 199534                  2                     0    95            0
# 199535                  2                    30    94            0
# 199536                  2                    17    94            0
# 199537                  2                    52    95            0
# 199538                  2                    52    95            0
# 199539                  0                     0    95            0
# 199540                  2                    52    95            0
# 199541                  2                    50    94            0
# 199542                  2                    52    95            1
# 199543                  0                     0    94            0
# 199544                  2                     0    94            0
# 199545                  2                    52    95            0
# 199546                  2                    52    94            0
# 199547                  2                    52    94            0
# 199548                  2                    52    94            0
# 199549                  2                    52    94            0
# 199550                  0                     0    94            0
# 199551                  2                     0    95            0
# 199552                  2                    36    94            0
# ...                   ...                   ...   ...          ...
# 299255                  2                    30    94            0
# 299256                  0                     0    95            0
# 299257                  2                     0    94            0
# 299258                  2                    52    95            0
# 299259                  2                    52    94            0
# 299260                  2                     1    94            0
# 299261                  0                     0    94            0
# 299262                  0                     0    95            0
# 299263                  2                    48    95            0
# 299264                  2                    52    95            0
# 299265                  2                    26    95            0
# 299266                  0                     0    95            0
# 299267                  2                    52    95            0
# 299268                  2                     0    95            0
# 299269                  0                     0    94            0
# 299270                  2                    52    95            0
# 299271                  2                    27    95            0
# 299272                  2                    52    94            0
# 299273                  2                     0    94            0
# 299274                  2                    52    94            0
# 299275                  2                    52    95            0
# 299276                  0                     0    95            0
# 299277                  2                     1    95            0
# 299278                  2                     0    95            0
# 299279                  0                     0    95            0
# 299280                  0                     0    95            0
# 299281                  2                    52    95            0
# 299282                  2                    52    94            0
# 299283                  2                    52    95            0
# 299284                  2                     0    94            0
#
# [99762 rows x 41 columns]

# %%
def remove_columns_with_null_values(df,threshold):
    """
    Removes columns with missing values over a certain percent
    
    Arguments: df:pd.DataFrame, threshold:float
    
    Returns: x:pd.DataFrame
    """
    
    #Assign df to x
    x = df

    #select columns with more than threshold
    x = x.dropna(thresh=threshold*len(x), axis=1)
    #replace all other missing values with string
    x = x.replace(np.nan, 'null_value', regex=True)
    return x
    
group = remove_columns_with_null_values(group,0.95)

# %%
summary(group)
# Out:
# number of rows: 299285
# number of columns: 37
# List of columns ['age' 'class_of_worker' 'industry_code' 'occupation_code' 'education'
#  'wage_per_hour' 'enrolled_in_edu_inst_lastwk' 'marital_status'
#  'major_industry_code' 'major_occupation_code' 'race' 'hispanic_origin'
#  'sex' 'member_of_labor_union' 'reason_for_unemployment'
#  'full_parttime_employment_stat' 'capital_gains' 'capital_losses'
#  'dividend_from_Stocks' 'tax_filer_status' 'region_of_previous_residence'
#  'state_of_previous_residence' 'd_household_family_stat'
#  'd_household_summary' 'live_1_year_ago' 'num_person_Worked_employer'
#  'family_members_under_18' 'country_father' 'country_mother' 'country_self'
#  'citizenship' 'business_or_self_employed'
#  'fill_questionnaire_veteran_admin' 'veterans_benefits'
#  'weeks_worked_in_year' 'year' 'income_level']
#    age                 class_of_worker  industry_code  occupation_code  \
# 0   73                 Not in universe              0                0
# 1   58  Self-employed-not incorporated              4               34
# 2   18                 Not in universe              0                0
# 3    9                 Not in universe              0                0
# 4   10                 Not in universe              0                0
#
#                     education  wage_per_hour enrolled_in_edu_inst_lastwk  \
# 0        High school graduate              0             Not in universe
# 1  Some college but no degree              0             Not in universe
# 2                  10th grade              0                 High school
# 3                    Children              0             Not in universe
# 4                    Children              0             Not in universe
#
#   marital_status          major_industry_code  \
# 0        Widowed  Not in universe or children
# 1       Divorced                 Construction
# 2  Never married  Not in universe or children
# 3  Never married  Not in universe or children
# 4  Never married  Not in universe or children
#
#                  major_occupation_code     ...      country_father  \
# 0                      Not in universe     ...       United-States
# 1  Precision production craft & repair     ...       United-States
# 2                      Not in universe     ...             Vietnam
# 3                      Not in universe     ...       United-States
# 4                      Not in universe     ...       United-States
#
#   country_mother   country_self                         citizenship  \
# 0  United-States  United-States   Native- Born in the United States
# 1  United-States  United-States   Native- Born in the United States
# 2        Vietnam        Vietnam  Foreign born- Not a citizen of U S
# 3  United-States  United-States   Native- Born in the United States
# 4  United-States  United-States   Native- Born in the United States
#
#   business_or_self_employed fill_questionnaire_veteran_admin  \
# 0                         0                  Not in universe
# 1                         0                  Not in universe
# 2                         0                  Not in universe
# 3                         0                  Not in universe
# 4                         0                  Not in universe
#
#    veterans_benefits  weeks_worked_in_year  year income_level
# 0                  2                     0    95            0
# 1                  2                    52    94            0
# 2                  2                     0    95            0
# 3                  0                     0    94            0
# 4                  0                     0    94            0
#
# [5 rows x 37 columns]

# %%
continuous_variables = ['age', 
                        'wage_per_hour',
                        'capital_gains',
                        'capital_losses',
                        'dividend_from_Stocks', 
                        'weeks_worked_in_year'
                       ]

def group_low_frequency_categories(df,threshold):
    """
    Groups low frequency categories with less 
    than threshold
    
    Arguments: df:pd.DataFrame,threshold:float
    
    Returns: x:pd.DataFrame
    """
    
    #Assign df to x
    x = df
    
    categories = df.drop(continuous_variables,axis=1)
    cols = categories.columns.values
    for col in cols:
        counts= categories[col].value_counts()
        length = categories[col].count()
        values = categories[col].unique()
        for value in values:
            if counts[value] < (length * threshold):
                categories[col].replace(value,'Other',inplace=True)
        for col in categories.columns.values:
            x[col] = categories[col]
            
    return x
            

group = group_low_frequency_categories(group,0.05)

# %%
summary(group)
# Out:
# number of rows: 299285
# number of columns: 37
# List of columns ['age' 'class_of_worker' 'industry_code' 'occupation_code' 'education'
#  'wage_per_hour' 'enrolled_in_edu_inst_lastwk' 'marital_status'
#  'major_industry_code' 'major_occupation_code' 'race' 'hispanic_origin'
#  'sex' 'member_of_labor_union' 'reason_for_unemployment'
#  'full_parttime_employment_stat' 'capital_gains' 'capital_losses'
#  'dividend_from_Stocks' 'tax_filer_status' 'region_of_previous_residence'
#  'state_of_previous_residence' 'd_household_family_stat'
#  'd_household_summary' 'live_1_year_ago' 'num_person_Worked_employer'
#  'family_members_under_18' 'country_father' 'country_mother' 'country_self'
#  'citizenship' 'business_or_self_employed'
#  'fill_questionnaire_veteran_admin' 'veterans_benefits'
#  'weeks_worked_in_year' 'year' 'income_level']
#    age  class_of_worker industry_code occupation_code  \
# 0   73  Not in universe             0               0
# 1   58            Other         Other           Other
# 2   18  Not in universe             0               0
# 3    9  Not in universe             0               0
# 4   10  Not in universe             0               0
#
#                     education  wage_per_hour enrolled_in_edu_inst_lastwk  \
# 0        High school graduate              0             Not in universe
# 1  Some college but no degree              0             Not in universe
# 2                       Other              0                       Other
# 3                    Children              0             Not in universe
# 4                    Children              0             Not in universe
#
#   marital_status          major_industry_code major_occupation_code  \
# 0          Other  Not in universe or children       Not in universe
# 1          Other                        Other                 Other
# 2  Never married  Not in universe or children       Not in universe
# 3  Never married  Not in universe or children       Not in universe
# 4  Never married  Not in universe or children       Not in universe
#
#       ...      country_father country_mother   country_self  \
# 0     ...       United-States  United-States  United-States
# 1     ...       United-States  United-States  United-States
# 2     ...               Other          Other          Other
# 3     ...       United-States  United-States  United-States
# 4     ...       United-States  United-States  United-States
#
#                          citizenship business_or_self_employed  \
# 0  Native- Born in the United States                         0
# 1  Native- Born in the United States                         0
# 2                              Other                         0
# 3  Native- Born in the United States                         0
# 4  Native- Born in the United States                         0
#
#   fill_questionnaire_veteran_admin  veterans_benefits  weeks_worked_in_year  \
# 0                  Not in universe                  2                     0
# 1                  Not in universe                  2                    52
# 2                  Not in universe                  2                     0
# 3                  Not in universe                  0                     0
# 4                  Not in universe                  0                     0
#
#    year income_level
# 0    95            0
# 1    94            0
# 2    95            0
# 3    94            0
# 4    94            0
#
# [5 rows x 37 columns]

# %%
#split back into train and test data sets

# %%
#visualisation here

# %%
def scale_numeric_columns(df):
    """
    Used to scale numeric columns for PCA
    
    Arguments: df - pd.DataFrame
    
    Returns: x - pd.DataFrame
    """
    
    #Assign df to x
    x = df
    
    scaler = MinMaxScaler()
    numeric = x[continuous_variables]
    scaler.fit(numeric)
    numeric = scaler.transform(numeric)
    numeric = pd.DataFrame(numeric,
                           columns=continuous_variables)
    for col in numeric.columns.values:
        x[col] = numeric[col]
    return x

group = scale_numeric_columns(group)

# %%
def encode_categorical_columns(df):
    """
    Encodes all cateogrical columns as numeric
    
    Arguments: df - pd.DataFrame
    
    Returns: x - pd.DataFrame
    """
    
    #Assign df to x
    x = df
    
    le = LabelEncoder()
    for col in x.columns.values:
        if x[col].dtypes == 'object':
            data = x[col]
            le.fit(data.values.astype(str))
            x[col] = le.transform(data.astype(str))
    
    return x 

group = encode_categorical_columns(group)

# %%
summary(group)
# Out:
# number of rows: 299285
# number of columns: 37
# List of columns ['age' 'class_of_worker' 'industry_code' 'occupation_code' 'education'
#  'wage_per_hour' 'enrolled_in_edu_inst_lastwk' 'marital_status'
#  'major_industry_code' 'major_occupation_code' 'race' 'hispanic_origin'
#  'sex' 'member_of_labor_union' 'reason_for_unemployment'
#  'full_parttime_employment_stat' 'capital_gains' 'capital_losses'
#  'dividend_from_Stocks' 'tax_filer_status' 'region_of_previous_residence'
#  'state_of_previous_residence' 'd_household_family_stat'
#  'd_household_summary' 'live_1_year_ago' 'num_person_Worked_employer'
#  'family_members_under_18' 'country_father' 'country_mother' 'country_self'
#  'citizenship' 'business_or_self_employed'
#  'fill_questionnaire_veteran_admin' 'veterans_benefits'
#  'weeks_worked_in_year' 'year' 'income_level']
#         age  class_of_worker  industry_code  occupation_code  education  \
# 0  0.811111                2              0                0          4
# 1  0.644444                3              2                1          6
# 2  0.200000                2              0                0          5
# 3  0.100000                2              0                0          3
# 4  0.111111                2              0                0          3
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0            0.0                            1               4
# 1            0.0                            1               4
# 2            0.0                            2               3
# 3            0.0                            1               3
# 4            0.0                            1               3
#
#    major_industry_code  major_occupation_code      ...       country_father  \
# 0                    1                      1      ...                    2
# 1                    2                      2      ...                    2
# 2                    1                      1      ...                    1
# 3                    1                      1      ...                    2
# 4                    1                      1      ...                    2
#
#    country_mother  country_self  citizenship  business_or_self_employed  \
# 0               2             2            1                          0
# 1               2             2            1                          0
# 2               1             1            2                          0
# 3               2             2            1                          0
# 4               2             2            1                          0
#
#    fill_questionnaire_veteran_admin  veterans_benefits  weeks_worked_in_year  \
# 0                                 1                  1                   0.0
# 1                                 1                  1                   1.0
# 2                                 1                  1                   0.0
# 3                                 1                  0                   0.0
# 4                                 1                  0                   0.0
#
#    year  income_level
# 0    95             0
# 1    94             0
# 2    95             0
# 3    94             0
# 4    94             0
#
# [5 rows x 37 columns]

# %%
train_length = len(df_train.index)
#split back into train and test
train = pd.DataFrame()
test  = pd.DataFrame()

if group.shape[0] > train_length: # len(df) > 10 would also work
    train = group[:train_length]
    test  = group[train_length:]
    
print(len(train.index))
print(len(test.index))
# Out:
# 199523
# 99762

# %%
X_train,y_train = train.drop(['income_level'],axis=1),train['income_level']
X_test, y_test  = test.drop(['income_level'],axis=1),test['income_level']

# %%
summary(train)
summary(test)
# Out:
# number of rows: 199523
# number of columns: 37
# List of columns ['age' 'class_of_worker' 'industry_code' 'occupation_code' 'education'
#  'wage_per_hour' 'enrolled_in_edu_inst_lastwk' 'marital_status'
#  'major_industry_code' 'major_occupation_code' 'race' 'hispanic_origin'
#  'sex' 'member_of_labor_union' 'reason_for_unemployment'
#  'full_parttime_employment_stat' 'capital_gains' 'capital_losses'
#  'dividend_from_Stocks' 'tax_filer_status' 'region_of_previous_residence'
#  'state_of_previous_residence' 'd_household_family_stat'
#  'd_household_summary' 'live_1_year_ago' 'num_person_Worked_employer'
#  'family_members_under_18' 'country_father' 'country_mother' 'country_self'
#  'citizenship' 'business_or_self_employed'
#  'fill_questionnaire_veteran_admin' 'veterans_benefits'
#  'weeks_worked_in_year' 'year' 'income_level']
#         age  class_of_worker  industry_code  occupation_code  education  \
# 0  0.811111                2              0                0          4
# 1  0.644444                3              2                1          6
# 2  0.200000                2              0                0          5
# 3  0.100000                2              0                0          3
# 4  0.111111                2              0                0          3
#
#    wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 0            0.0                            1               4
# 1            0.0                            1               4
# 2            0.0                            2               3
# 3            0.0                            1               3
# 4            0.0                            1               3
#
#    major_industry_code  major_occupation_code      ...       country_father  \
# 0                    1                      1      ...                    2
# 1                    2                      2      ...                    2
# 2                    1                      1      ...                    1
# 3                    1                      1      ...                    2
# 4                    1                      1      ...                    2
#
#    country_mother  country_self  citizenship  business_or_self_employed  \
# 0               2             2            1                          0
# 1               2             2            1                          0
# 2               1             1            2                          0
# 3               2             2            1                          0
# 4               2             2            1                          0
#
#    fill_questionnaire_veteran_admin  veterans_benefits  weeks_worked_in_year  \
# 0                                 1                  1                   0.0
# 1                                 1                  1                   1.0
# 2                                 1                  1                   0.0
# 3                                 1                  0                   0.0
# 4                                 1                  0                   0.0
#
#    year  income_level
# 0    95             0
# 1    94             0
# 2    95             0
# 3    94             0
# 4    94             0
#
# [5 rows x 37 columns]
# number of rows: 99762
# number of columns: 37
# List of columns ['age' 'class_of_worker' 'industry_code' 'occupation_code' 'education'
#  'wage_per_hour' 'enrolled_in_edu_inst_lastwk' 'marital_status'
#  'major_industry_code' 'major_occupation_code' 'race' 'hispanic_origin'
#  'sex' 'member_of_labor_union' 'reason_for_unemployment'
#  'full_parttime_employment_stat' 'capital_gains' 'capital_losses'
#  'dividend_from_Stocks' 'tax_filer_status' 'region_of_previous_residence'
#  'state_of_previous_residence' 'd_household_family_stat'
#  'd_household_summary' 'live_1_year_ago' 'num_person_Worked_employer'
#  'family_members_under_18' 'country_father' 'country_mother' 'country_self'
#  'citizenship' 'business_or_self_employed'
#  'fill_questionnaire_veteran_admin' 'veterans_benefits'
#  'weeks_worked_in_year' 'year' 'income_level']
#              age  class_of_worker  industry_code  occupation_code  education  \
# 199523  0.422222                1              2                1          5
# 199524  0.488889                3              2                1          5
# 199525  0.022222                0              0                0          0
# 199526  0.388889                1              2                1          1
# 199527  0.544444                1              2                1          1
#
#         wage_per_hour  enrolled_in_edu_inst_lastwk  marital_status  \
# 199523            0.0                            0               0
# 199524            0.0                            0               0
# 199525            0.0                            0               1
# 199526            0.0                            0               4
# 199527            0.0                            0               4
#
#         major_industry_code  major_occupation_code      ...       \
# 199523                    2                      2      ...
# 199524                    2                      2      ...
# 199525                    0                      0      ...
# 199526                    2                      2      ...
# 199527                    2                      2      ...
#
#         country_father  country_mother  country_self  citizenship  \
# 199523               1               1             1            2
# 199524               0               0             0            0
# 199525               0               0             0            0
# 199526               0               0             0            0
# 199527               0               0             0            0
#
#         business_or_self_employed  fill_questionnaire_veteran_admin  \
# 199523                          0                                 0
# 199524                          0                                 0
# 199525                          0                                 0
# 199526                          1                                 0
# 199527                          0                                 0
#
#         veterans_benefits  weeks_worked_in_year  year  income_level
# 199523                  1              0.230769    95             0
# 199524                  1              0.500000    95             0
# 199525                  0              0.000000    95             0
# 199526                  1              1.000000    94             0
# 199527                  1              0.961538    95             0
#
# [5 rows x 37 columns]

# %%
# Perform PCA to reduce dimensionality of datasets
pca = PCA(n_components=len(X_train.columns.values))
pca.fit(X_train)

#The amount of variance that each PC explains
var= pca.explained_variance_ratio_

#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

plt.plot(var1)

# %%
print(var1)
# Out:
# [  39.19   55.29   64.39   72.47   79.08   83.64   86.47   88.96   91.19
#    92.63   93.8    94.7    95.53   96.31   96.92   97.42   97.9    98.3
#    98.65   98.98   99.29   99.49   99.64   99.76   99.85   99.93   99.97
#    99.99  100.01  100.02  100.02  100.02  100.02  100.02  100.02  100.02]

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([ 0.39186755,  0.55284146,  0.64381159,  0.72459847,  0.7906913 ,
#         0.83624852,  0.86457499,  0.88943176,  0.9116864 ,  0.92606642,
#         0.93776639,  0.94674246,  0.95499798,  0.96283157,  0.96897953,
#         0.97395144,  0.97872958,  0.98275969,  0.98628127,  0.9895389 ,
#         0.99262924,  0.99465376,  0.99617772,  0.99737954,  0.99831583,
#         0.99911797,  0.99947142,  0.99965713,  0.99982453,  0.9999428 ,
#         0.9999789 ,  0.99999959,  1.        ,  1.        ,  1.        ,  1.        ])

# %%
# Perform PCA to reduce dimensionality of datasets
pca = PCA(n_components=10)
pca.fit(X_train)

#The amount of variance that each PC explains
var= pca.explained_variance_ratio_

#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

plt.plot(var1)

# %%
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()

X_transformed = pca.fit_transform(X_train)

classifier.fit(X_transformed,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
X_test_transformed = pca.transform(X_test)
pred = classifier.predict(X_test_transformed)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
classifier.score(X_test_transformed,y_test)
# Out:
# 0.85504500711693832

# %%
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
classifier.score(X_test,y_test)
# Out:
# 0.811070347426876
